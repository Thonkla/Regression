# %%
import numpy as np
import matplotlib.pyplot as plt

# Set a random seed for reproducibility
np.random.seed(42)

# Generate random input data | data between 0-1, 100 numbers
X = 2 * np.random.rand(100, 1)

# Corresponding output data using a linear equation y = 5X - 5 + noise
y = 5*X - 5 + np.random.randn(100, 1)

# %%
from linear_regression import *

test_2D = LinearRegression(X,y)

# %%
test_2D.loss()
# Out:
# 88705.04746481139

# %%
test_2D.fit()
# Out:
# loss=80.66
# array([[ 4.77011339],
#        [-4.78490384]])

# %%
test_2D.predict(2)
# Out:
# array([4.75532293])

# %%
test_2D.plot()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set a random seed for reproducibility
np.random.seed(42)

# Generate random input data | data between 0-1, 100 numbers
X1 = 2 * np.random.rand(100, 1) 
X2 = -2 * np.random.rand(100, 1)
X = np.concatenate((X1,X2), axis=1)

# Corresponding output data using a linear equation y = -5X1 + 2X2 + 5 + noise
y = -5*X1 + 2*X2 + 5 + np.random.randn(100, 1)

# %%
#from linear_regression import *

test_3D = LinearRegression(X,y)

# %%
test_3D.loss()
# Out:
# 135448.36460339633

# %%
test_3D.fit()
# Out:
# loss=94.57
# array([[-5.17086266],
#        [ 1.64034429],
#        [ 4.91061004]])

# %%
test_3D.plot()

# %% [markdown]
# Load Data

# %%
# !kaggle datasets download -d ashydv/advertising-dataset
# Out:
# advertising-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import pandas as pd 
raw_df = pd.read_csv("advertising-dataset/advertising.csv")

# %%
raw_df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# Preprocessing Data

# %%
df = np.asarray(raw_df)

# %%
df[:5]
# Out:
# array([[230.1,  37.8,  69.2,  22.1],
#        [ 44.5,  39.3,  45.1,  10.4],
#        [ 17.2,  45.9,  69.3,  12. ],
#        [151.5,  41.3,  58.5,  16.5],
#        [180.8,  10.8,  58.4,  17.9]])

# %%
df = normalization(df)
df[:5]
# Out:
# array([[0.77631579, 0.12753036, 0.23346829, 0.0745614 ],
#        [0.15013495, 0.13259109, 0.15215924, 0.03508772],
#        [0.05802969, 0.1548583 , 0.23380567, 0.04048583],
#        [0.5111336 , 0.13933873, 0.19736842, 0.05566802],
#        [0.6099865 , 0.03643725, 0.19703104, 0.06039136]])

# %%
X = df[:, :-1]
Y = df[:,-1:]

# %%
X[:5]
# Out:
# array([[0.77631579, 0.12753036, 0.23346829],
#        [0.15013495, 0.13259109, 0.15215924],
#        [0.05802969, 0.1548583 , 0.23380567],
#        [0.5111336 , 0.13933873, 0.19736842],
#        [0.6099865 , 0.03643725, 0.19703104]])

# %%
Y[:5]
# Out:
# array([[0.0745614 ],
#        [0.03508772],
#        [0.04048583],
#        [0.05566802],
#        [0.06039136]])

# %% [markdown]
# Training

# %%
model = LinearRegression(X,Y)

# %%
model.fit()
# Out:
# loss=0.01
# array([[0.05444578],
#        [0.10700123],
#        [0.00033566],
#        [0.01560433]])

# %% [markdown]
# Visualize

# %%
model.loss()
# Out:
# 0.0061603072853261085

# %%
model.plot()
# Out:
# Can be used only 1D or 2D data
